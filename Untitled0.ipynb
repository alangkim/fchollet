# %% [markdown]
# <a href="https://colab.research.google.com/github/arangc/fchollet/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## 코랩에서 실행할시
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

path = '/content/drive/folders/딥러닝_공모전'
file_list = os.listdir(path)
len(file_list)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-5334c8e0c594> in <module>()
#       2
#       3 path = '/content/drive/folders/딥러닝_공모전'
# ----> 4 file_list = os.listdir(path)
#       5 len(file_list)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/folders/딥러닝_공모전'

# %%
file_list
# Out:
# ['Train.csv',
#  'Test.csv',
#  '김가은',
#  '김준원',
#  '윤한세',
#  '이건이',
#  '이주현',
#  'Images',
#  'Untitled0.ipynb',
#  'Images_total.zip']

# %%
# !unzip /content/drive/MyDrive/딥러닝_공모전/Images_total.zip
# Out:
# unzip:  cannot find or open /content/drive/MyDrive/딥러닝_공모전/Images_total.zip, /content/drive/MyDrive/딥러닝_공모전/Images_total.zip.zip or /content/drive/MyDrive/딥러닝_공모전/Images_total.zip.ZIP.

# %%
len(os.listdir('Images'))
# Out:
# 2699

# %%
## 데이터 불러오기
import pandas as pd

train_csv = pd.read_csv('/content/drive/MyDrive/딥러닝_공모전/Train.csv')
test_csv = pd.read_csv('/content/drive/MyDrive/딥러닝_공모전/Test.csv')

# %%
print(train_csv.shape, test_csv.shape)
# Out:
# (1619, 2) (1080, 1)

# %%
print(train_csv[:1000]['Label'].sum())
print(train_csv[1000:]['Label'].sum())
print(train_csv['Label'].sum())
# Out:
# 495
# 314
# 809

# %%
train_data = train_csv[:1000].reset_index(drop=True)
train_data.head()
# Out:
#                Image_id  Label
# 0  id_02amazy34fgh2.jpg      1
# 1  id_02mh3w48pmyc9.jpg      0
# 2  id_02rpb463h9d3w.jpg      0
# 3  id_02wc3jeeao8ol.jpg      1
# 4  id_03t2hapb8wz8p.jpg      1

# %%
val_data = train_csv[1000:].reset_index(drop=True)
val_data.head()
# Out:
#                Image_id  Label
# 0  id_mhwsjzmaacaeu.jpg      0
# 1  id_micmqems98pps.jpg      0
# 2  id_mj1nud27n3jmr.jpg      0
# 3  id_mj4uwr8uql332.jpg      1
# 4  id_mk8l6y03hk7wc.jpg      0

# %%
import shutil, pathlib

original_dir = pathlib.Path("./Images") 
new_base_dir = pathlib.Path("./data")

# %%
train_pest_o = train_data[train_data["Label"] == 1] 
train_pest_x = train_data[train_data["Label"] == 0]
val_pest_o = val_data[val_data["Label"] == 1] 
val_pest_x = val_data[val_data["Label"] == 0]

# %%
file_names = os.listdir(original_dir)

# %%
file_names
# Out:
# ['id_ixw1xbrtidxms.jpg',
#  'id_p1gi53axpcchr.jpg',
#  'id_sfvcij8ne337l.jpg',
#  'id_bd5ri69rptqug.jpg',
#  'id_ukf2etwrvahyf.jpg',
#  'id_6fg87l8h3ka10.jpg',
#  'id_44q82lq0haq7s.jpg',
#  'id_v1jpjln5wvu4b.jpg',
#  'id_sn8p1ituhofx4.jpg',
#  'id_7jv7er6lzmx05.jpg',
#  'id_75g2ut71g3uzi.jpg',
#  'id_lmxht9utayqde.jpg',
#  'id_zsts4k0kqtywj.jpg',
#  'id_f7vst89z8u1iq.jpg',
#  'id_ao0s59swr97at.jpg',
#  'id_whzmoee1m9nwc.jpg',
#  'id_w0gc08p0bynmv.jpg',
#  'id_l1ixknyd0j65l.jpg',
#  'id_wsasfk5bkj7au.jpg',
#  'id_fkbursnmd6lhy.jpg',
#  'id_wmd839qbztxkr.jpg',
#  'id_ufzjqr8ou3wsc.jpg',
#  'id_d16hwmowwlps1.jpg',
#  'id_o6cnd11rn4rq6.jpg',
#  'id_03t2hapb8wz8p.jpg',
#  'id_xoszqfw7r7yns.jpg',
#  'id_e5ojnfaxfdcst.jpg',
#  'id_nxp6d4nr9zmkp.jpg',
#  'id_rpfpq3fkrppqu.jpg',
#  'id_dkzvwmnm20lcm.jpg',
#  'id_5yumb1f3akbih.jpg',
#  'id_6q3v16yz1z4qg.jpg',
#  'id_5riby4jh3w2tt.jpg',
#  'id_js800e2lphnjp.jpg',
#  'id_o21uilop3dllb.jpg',
#  'id_dsfqaoey5kxsm.jpg',
#  'id_u8l2shzgw06eu.jpg',
# ...

# %%
num = 0
ber = 0
for name in file_names :
    for i in train_pest_o["Image_id"] :
        if name == i :
            src = os.path.join(original_dir, name)
            dst = 'pest'+ str(num) + '_train' + '.jpg'
            dst = os.path.join(original_dir, dst)
            os.rename(src, dst)
            num += 1 # train 이름 바꾸기 - pest
    for j in val_pest_o["Image_id"] :
        if name == j :
            src = os.path.join(original_dir, name)
            dst = 'pest'+ str(ber) + '_val' + '.jpg'
            dst = os.path.join(original_dir, dst)
            os.rename(src, dst)
            ber += 1 # val 이름 바꾸기 - pest

# %%
num = 0
ber = 0
for name in file_names :
    for i in train_pest_x["Image_id"] :
        if name == i :
            src = os.path.join(original_dir, name)
            dst = 'nopest'+ str(num) + '_train' + '.jpg'
            dst = os.path.join(original_dir, dst)
            os.rename(src, dst)
            num += 1 # train 이름 바꾸기 - nopest
    for j in val_pest_x["Image_id"] :
        if name == j :
            src = os.path.join(original_dir, name)
            dst = 'nopest'+ str(ber) + '_val' + '.jpg'
            dst = os.path.join(original_dir, dst)
            os.rename(src, dst)
            ber += 1 # val 이름 바꾸기 - nopest

# %%
file_names = os.listdir(original_dir)
file_names # train+val에 속한 것들은 모두 이름 변경 완료
# Out:
# ['pest153_train.jpg',
#  'id_sfvcij8ne337l.jpg',
#  'id_bd5ri69rptqug.jpg',
#  'nopest144_val.jpg',
#  'nopest18_train.jpg',
#  'id_6fg87l8h3ka10.jpg',
#  'pest185_train.jpg',
#  'id_v1jpjln5wvu4b.jpg',
#  'nopest437_train.jpg',
#  'id_sn8p1ituhofx4.jpg',
#  'id_75g2ut71g3uzi.jpg',
#  'pest292_val.jpg',
#  'nopest66_train.jpg',
#  'nopest21_train.jpg',
#  'id_ao0s59swr97at.jpg',
#  'id_whzmoee1m9nwc.jpg',
#  'nopest96_val.jpg',
#  'pest13_val.jpg',
#  'nopest144_train.jpg',
#  'nopest151_val.jpg',
#  'id_l1ixknyd0j65l.jpg',
#  'nopest137_val.jpg',
#  'nopest70_train.jpg',
#  'pest44_train.jpg',
#  'pest0_train.jpg',
#  'id_rpfpq3fkrppqu.jpg',
#  'id_dkzvwmnm20lcm.jpg',
#  'nopest57_val.jpg',
#  'id_5yumb1f3akbih.jpg',
#  'pest90_val.jpg',
#  'id_o21uilop3dllb.jpg',
#  'id_u8l2shzgw06eu.jpg',
#  'pest348_train.jpg',
#  'nopest462_train.jpg',
#  'nopest35_train.jpg',
#  'pest81_val.jpg',
#  'id_eeh0s4d3ykqbl.jpg',
#  'id_9stj11h5sb6nq.jpg',
#  'pest212_val.jpg',
# ...

# %%
train_list = []
for tra in file_names:
    if '_train' in tra:
        train_list.append(tra)


print(train_list)
print(len(train_list))
# Out:
# ['pest153_train.jpg', 'nopest18_train.jpg', 'pest185_train.jpg', 'nopest437_train.jpg', 'nopest66_train.jpg', 'nopest21_train.jpg', 'nopest144_train.jpg', 'nopest70_train.jpg', 'pest44_train.jpg', 'pest0_train.jpg', 'pest348_train.jpg', 'nopest462_train.jpg', 'nopest35_train.jpg', 'nopest241_train.jpg', 'nopest441_train.jpg', 'nopest481_train.jpg', 'pest178_train.jpg', 'nopest159_train.jpg', 'pest491_train.jpg', 'nopest289_train.jpg', 'pest215_train.jpg', 'nopest162_train.jpg', 'pest82_train.jpg', 'nopest302_train.jpg', 'nopest489_train.jpg', 'nopest32_train.jpg', 'nopest249_train.jpg', 'nopest252_train.jpg', 'pest240_train.jpg', 'pest88_train.jpg', 'pest316_train.jpg', 'pest259_train.jpg', 'pest200_train.jpg', 'nopest16_train.jpg', 'nopest81_train.jpg', 'pest298_train.jpg', 'pest81_train.jpg', 'nopest301_train.jpg', 'nopest315_train.jpg', 'nopest135_train.jpg', 'pest114_train.jpg', 'pest7_train.jpg', 'pest475_train.jpg', 'nopest300_train.jpg', 'nopest251_train.jpg', 'nopest260_train
# ...

# %%
os.listdir(original_dir)
# Out:
# ['pest153_train.jpg',
#  'id_sfvcij8ne337l.jpg',
#  'id_bd5ri69rptqug.jpg',
#  'nopest144_val.jpg',
#  'nopest18_train.jpg',
#  'id_6fg87l8h3ka10.jpg',
#  'pest185_train.jpg',
#  'id_v1jpjln5wvu4b.jpg',
#  'nopest437_train.jpg',
#  'id_sn8p1ituhofx4.jpg',
#  'id_75g2ut71g3uzi.jpg',
#  'pest292_val.jpg',
#  'nopest66_train.jpg',
#  'nopest21_train.jpg',
#  'id_ao0s59swr97at.jpg',
#  'id_whzmoee1m9nwc.jpg',
#  'nopest96_val.jpg',
#  'pest13_val.jpg',
#  'nopest144_train.jpg',
#  'nopest151_val.jpg',
#  'id_l1ixknyd0j65l.jpg',
#  'nopest137_val.jpg',
#  'nopest70_train.jpg',
#  'pest44_train.jpg',
#  'pest0_train.jpg',
#  'id_rpfpq3fkrppqu.jpg',
#  'id_dkzvwmnm20lcm.jpg',
#  'nopest57_val.jpg',
#  'id_5yumb1f3akbih.jpg',
#  'pest90_val.jpg',
#  'id_o21uilop3dllb.jpg',
#  'id_u8l2shzgw06eu.jpg',
#  'pest348_train.jpg',
#  'nopest462_train.jpg',
#  'nopest35_train.jpg',
#  'pest81_val.jpg',
#  'id_eeh0s4d3ykqbl.jpg',
#  'id_9stj11h5sb6nq.jpg',
#  'pest212_val.jpg',
# ...

# %%
dir = new_base_dir/'train'
os.makedirs(dir) # 폴더 생성
for fname in train_list:
    shutil.move(src=original_dir / fname, dst= dir / fname)
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# <ipython-input-62-550c0e3ac7ae> in <module>()
#       1 dir = new_base_dir/'train'
# ----> 2 os.makedirs(dir) # 폴더 생성
#       3 for fname in train_list:
#       4     shutil.move(src=original_dir / fname, dst= dir / fname)
#
# /usr/lib/python3.7/os.py in makedirs(name, mode, exist_ok)
#     221             return
#     222     try:
# --> 223         mkdir(name, mode)
#     224     except OSError:
#     225         # Cannot rely on checking for EEXIST, since the operating system
#
# FileExistsError: [Errno 17] File exists: 'data/train'

# %%
os.listdir('data/train')
# Out:
# []

# %%
train_list[0]
# Out:
# 'pest153_train.jpg'

# %%
val_list=[]
for val in file_names:
    if '_val' in val:
        val_list.append(val)

print(val_list)
print(len(val_list))
# Out:
# ['nopest144_val.jpg', 'pest292_val.jpg', 'nopest96_val.jpg', 'pest13_val.jpg', 'nopest151_val.jpg', 'nopest137_val.jpg', 'nopest57_val.jpg', 'pest90_val.jpg', 'pest81_val.jpg', 'pest212_val.jpg', 'nopest204_val.jpg', 'nopest7_val.jpg', 'nopest251_val.jpg', 'nopest237_val.jpg', 'nopest26_val.jpg', 'nopest113_val.jpg', 'pest243_val.jpg', 'pest55_val.jpg', 'nopest226_val.jpg', 'nopest164_val.jpg', 'nopest218_val.jpg', 'pest73_val.jpg', 'nopest281_val.jpg', 'nopest248_val.jpg', 'pest252_val.jpg', 'pest259_val.jpg', 'pest85_val.jpg', 'nopest236_val.jpg', 'nopest65_val.jpg', 'nopest275_val.jpg', 'pest157_val.jpg', 'pest170_val.jpg', 'nopest276_val.jpg', 'nopest302_val.jpg', 'pest155_val.jpg', 'pest112_val.jpg', 'pest225_val.jpg', 'pest208_val.jpg', 'pest31_val.jpg', 'pest224_val.jpg', 'nopest273_val.jpg', 'pest22_val.jpg', 'nopest154_val.jpg', 'pest108_val.jpg', 'nopest147_val.jpg', 'pest312_val.jpg', 'pest59_val.jpg', 'nopest110_val.jpg', 'pest301_val.jpg', 'pest304_val.jpg', 'pest207_val
# ...

# %%
new_base_dir
# Out:
# PosixPath('data')

# %%
import shutil 
filename = 'test.txt' 
src = '/home/banana/' 
dir = '/home/banana/txt/' 
shutil.move(src + filename, dir + filename)

# %%
def make_subset(subset_name, f_list):
    for category in ("pest", "nopest"):
        dir = new_base_dir / subset_name / category
        os.makedirs(dir) # 폴더 생성

        fnames = [f"{category}{i}.jpg" for i in range(len(f_list))]
        for fname in fnames:
            shutil.move(src=original_dir / fname,
                            dst=dir / fname)

# %%
import os
import shutil

if os.path.exists(new_base_dir):
    shutil.rmtree(new_base_dir)

# %%
make_subset('train', train_list)
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# <ipython-input-49-728170a80972> in <module>()
# ----> 1 make_subset('train', train_list)
#
# <ipython-input-48-aa882728387b> in make_subset(subset_name, f_list)
#       2     for category in ("pest", "nopest"):
#       3         dir = new_base_dir / subset_name / category
# ----> 4         os.makedirs(dir) # 폴더 생성
#       5
#       6         fnames = [f"{category}{i}.jpg" for i in range(len(f_list))]
#
# /usr/lib/python3.7/os.py in makedirs(name, mode, exist_ok)
#     221             return
#     222     try:
# --> 223         mkdir(name, mode)
#     224     except OSError:
#     225         # Cannot rely on checking for EEXIST, since the operating system
#
# FileExistsError: [Errno 17] File exists: 'data/train/pest'

# %%
dir
# Out:
# <function dir>

# %%
shutil.move(src=original_dir, dst= new_base_dir / "test" / "testset") # train/validation에 포함되지 않은 이미지를 testset으로 이동
# Out:
# PosixPath('/content/윤한세/test/testset')

# %%
file_names
# Out:
# ['pest61.jpg',
#  'pest67.jpg',
#  'id_sfvcij8ne337l.jpg',
#  'nopest319.jpg',
#  'nopest65.jpg',
#  'pest276.jpg',
#  'nopest211.jpg',
#  'id_bd5ri69rptqug.jpg',
#  'nopest74.jpg',
#  'nopest144_val.jpg',
#  'id_6fg87l8h3ka10.jpg',
#  'id_v1jpjln5wvu4b.jpg',
#  'id_sn8p1ituhofx4.jpg',
#  'id_75g2ut71g3uzi.jpg',
#  'pest292_val.jpg',
#  'nopest343.jpg',
#  'id_ao0s59swr97at.jpg',
#  'id_whzmoee1m9nwc.jpg',
#  'nopest96_val.jpg',
#  'pest13_val.jpg',
#  'nopest151_val.jpg',
#  'id_l1ixknyd0j65l.jpg',
#  'nopest188.jpg',
#  'nopest137_val.jpg',
#  'id_rpfpq3fkrppqu.jpg',
#  'id_dkzvwmnm20lcm.jpg',
#  'nopest57_val.jpg',
#  'pest8.jpg',
#  'pest278.jpg',
#  'pest287.jpg',
#  'id_5yumb1f3akbih.jpg',
#  'pest90_val.jpg',
#  'id_o21uilop3dllb.jpg',
#  'pest95.jpg',
#  'id_u8l2shzgw06eu.jpg',
#  'pest81_val.jpg',
#  'id_eeh0s4d3ykqbl.jpg',
#  'id_9stj11h5sb6nq.jpg',
#  'pest212_val.jpg',
#  'id_l9wgku4lvd4ai.jpg',
#  'nopest116.jpg',
#  'pest417.jpg',
#  'id_u5cgdvspkcd1t.jpg',
# ...

# %%
from keras.preprocessing import image
import matplotlib.pyplot as plt
# %matplotlib inline

img = image.load_img(os.path.join(path, train_data['Image_id'][0]), target_size=(250, 250))
plt.imshow(img)
plt.show()

# %%
from keras.preprocessing import image
import matplotlib.pyplot as plt
# %matplotlib inline

img = image.load_img(os.path.join(path, file_list[500]), target_size=(250, 250))
plt.imshow(img)
plt.show()

# %%
img2 = image.load_img(os.path.join(path, val_data['Image_id'][0]), target_size=(250, 250))
plt.imshow(img2)
plt.show()

# %%
import os, shutil, pathlib

original_dir = pathlib.Path("train")
new_base_dir = pathlib.Path("cats_vs_dogs_small")

def make_subset(subset_name, start_index, end_index):
    for category in ("cat", "dog"):
        dir = new_base_dir / subset_name / category
        os.makedirs(dir)
        fnames = [f"{category}.{i}.jpg" for i in range(start_index, end_index)]
        for fname in fnames:
            shutil.copyfile(src=original_dir / fname,
                            dst=dir / fname)

make_subset("train", start_index=0, end_index=1000)
make_subset("validation", start_index=1000, end_index=1500)
make_subset("test", start_index=1500, end_index=2500)

# %%
import os, shutil, pathlib

original_dir = pathlib.Path(path)
new_base_dir = pathlib.Path("pest")

def make_subset(subset_name, dataset):
    for category in ("pest", "nopest"):
        dir = new_base_dir / subset_name / category
        os.makedirs(dir)
        fnames = [f"{category}.{i}.jpg" for i in range(start_index, end_index)]
        for fname in fnames:
            shutil.copyfile(src=original_dir / fname,
                            dst=dir / fname)

# %%
# Out:
# ['id_02amazy34fgh2.jpg',
#  'id_02mh3w48pmyc9.jpg',
#  'id_02rpb463h9d3w.jpg',
#  'id_02wc3jeeao8ol.jpg',
#  'id_03t2hapb8wz8p.jpg',
#  'id_04xrxyd43rlgz.jpg',
#  'id_05gqx7h8y6iye.jpg',
#  'id_06le9g89kqth5.jpg',
#  'id_082w0qygo3eth.jpg',
#  'id_086yvmu3nnvbe.jpg',
#  'id_09v3am3ppzesz.jpg',
#  'id_0bbnpqpkpbod3.jpg',
#  'id_0bd0chrhwa88r.jpg',
#  'id_0d6mm3xcpbqkw.jpg',
#  'id_0ff2fm63gzxvs.jpg',
#  'id_0g00jpbynmgfr.jpg',
#  'id_0gur3rc3nuft9.jpg',
#  'id_0k7gdyyx5zunr.jpg',
#  'id_0klqzvk8id4bt.jpg',
#  'id_0mytnx3vd7ebk.jpg',
#  'id_0ncnn142aww4v.jpg',
#  'id_0qm8i331u09jq.jpg',
#  'id_0qrjnjx2nbbde.jpg',
#  'id_0t41fhqaaqux9.jpg',
#  'id_0t76933bwfswn.jpg',
#  'id_0t7gw6z26pabf.jpg',
#  'id_0ub75edrc3qvg.jpg',
#  'id_0unlhj59tv0p4.jpg',
#  'id_0vn4379vhh52p.jpg',
#  'id_0wq0ldha65pkf.jpg',
#  'id_0wtod6711rn7r.jpg',
#  'id_0xb2nvq2kqdst.jpg',
#  'id_0yb73f56l5r4f.jpg',
#  'id_0z6gb99lwj01f.jpg',
#  'id_0ztqu05sh2a8j.jpg',
#  'id_10gekjcx26yu7.jpg',
#  'id_10xmisqifmnpb.jpg',
# ...

# %%
len(train_data)
# Out:
# 1000

# %%
dir = new_base_dir / 'test' / 'cat'

# %%
dir
# Out:
# PosixPath('cats_vs_dogs_small/test/cat')

# %%
fnames = [f"{'dog'}.{i}.jpg" for i in range(0, 10000)]

# %%
fnames
# Out:
# ['dog.0.jpg',
#  'dog.1.jpg',
#  'dog.2.jpg',
#  'dog.3.jpg',
#  'dog.4.jpg',
#  'dog.5.jpg',
#  'dog.6.jpg',
#  'dog.7.jpg',
#  'dog.8.jpg',
#  'dog.9.jpg',
#  'dog.10.jpg',
#  'dog.11.jpg',
#  'dog.12.jpg',
#  'dog.13.jpg',
#  'dog.14.jpg',
#  'dog.15.jpg',
#  'dog.16.jpg',
#  'dog.17.jpg',
#  'dog.18.jpg',
#  'dog.19.jpg',
#  'dog.20.jpg',
#  'dog.21.jpg',
#  'dog.22.jpg',
#  'dog.23.jpg',
#  'dog.24.jpg',
#  'dog.25.jpg',
#  'dog.26.jpg',
#  'dog.27.jpg',
#  'dog.28.jpg',
#  'dog.29.jpg',
#  'dog.30.jpg',
#  'dog.31.jpg',
#  'dog.32.jpg',
#  'dog.33.jpg',
#  'dog.34.jpg',
#  'dog.35.jpg',
#  'dog.36.jpg',
#  'dog.37.jpg',
#  'dog.38.jpg',
#  'dog.39.jpg',
#  'dog.40.jpg',
#  'dog.41.jpg',
#  'dog.42.jpg',
#  'dog.43.jpg',
#  'dog.44.jpg',
#  'dog.45.jpg',
#  'dog.46.jpg',
#  'dog.47.jpg',
#  'dog.48.jpg',
#  'dog.49.jpg',
#  'dog.50.jpg',
#  'dog.51.jpg',
#  'dog.52.jpg',
#  'dog.53.jpg',
#  'dog.54.jpg',
#  'dog.55.jpg',
#  'dog.56.jpg',
#  'dog.57.jpg',
#  'dog.58.jpg',
# ...

# %%
os.listdir('cats_vs_dogs_small/test/dog')
# Out:
# ['dog.1804.jpg',
#  'dog.1863.jpg',
#  'dog.1820.jpg',
#  'dog.2261.jpg',
#  'dog.1646.jpg',
#  'dog.2232.jpg',
#  'dog.1773.jpg',
#  'dog.1774.jpg',
#  'dog.2499.jpg',
#  'dog.1917.jpg',
#  'dog.1541.jpg',
#  'dog.2481.jpg',
#  'dog.1528.jpg',
#  'dog.1522.jpg',
#  'dog.1922.jpg',
#  'dog.1900.jpg',
#  'dog.2355.jpg',
#  'dog.2102.jpg',
#  'dog.2094.jpg',
#  'dog.2441.jpg',
#  'dog.2160.jpg',
#  'dog.1734.jpg',
#  'dog.2126.jpg',
#  'dog.1991.jpg',
#  'dog.1808.jpg',
#  'dog.2402.jpg',
#  'dog.2294.jpg',
#  'dog.2321.jpg',
#  'dog.2054.jpg',
#  'dog.1615.jpg',
#  'dog.2318.jpg',
#  'dog.1547.jpg',
#  'dog.1697.jpg',
#  'dog.1676.jpg',
#  'dog.1883.jpg',
#  'dog.2130.jpg',
#  'dog.1736.jpg',
#  'dog.1610.jpg',
#  'dog.2002.jpg',
#  'dog.1854.jpg',
#  'dog.1865.jpg',
#  'dog.1912.jpg',
#  'dog.2095.jpg',
#  'dog.1655.jpg',
#  'dog.2162.jpg',
#  'dog.1754.jpg',
#  'dog.2016.jpg',
#  'dog.1892.jpg',
#  'dog.2141.jpg',
#  'dog.2427.jpg',
#  'dog.1923.jpg',
#  'dog.2360.jpg',
# ...

# %%
from tensorflow import keras
from tensorflow.keras import layers

inputs = keras.Input(shape=(180, 180, 3))
x = layers.Rescaling(1./255)(inputs)
x = layers.Conv2D(filters=32, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x) # depth는 크게 나머진 작게
x = layers.Flatten()(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs=inputs, outputs=outputs)

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_1 (InputLayer)        [(None, 180, 180, 3)]     0
#
#  rescaling (Rescaling)       (None, 180, 180, 3)       0
#
#  conv2d (Conv2D)             (None, 178, 178, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 89, 89, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 87, 87, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 43, 43, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 41, 41, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 20, 20, 128)      0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 18, 18, 256)       295168
#
#  max_pooling2d_3 (MaxPooling  (None, 9, 9, 256)        0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 7, 7, 256)         590080
#
#  flatten (Flatten)           (None, 12544)             0
#
#  dense (Dense)               (None, 1)                 12545
#
# ...

# %% [markdown]
# **Configuring the model for training**

# %%
model.compile(loss="binary_crossentropy",
              optimizer="rmsprop",
              metrics=["accuracy"])

# %% [markdown]
# ### Data preprocessing

# %% [markdown]
# **Using `image_dataset_from_directory` to read images**

# %%
from tensorflow.keras.utils import image_dataset_from_directory


train_dataset = image_dataset_from_directory(
    new_base_dir / "train",
    image_size=(180, 180),
    batch_size=32)
validation_dataset = image_dataset_from_directory(
    new_base_dir / "validation",
    image_size=(180, 180),
    batch_size=32)
test_dataset = image_dataset_from_directory(
    new_base_dir / "test",
    image_size=(180, 180),
    batch_size=32)
# Out:
# Found 2000 files belonging to 2 classes.
# Found 1000 files belonging to 2 classes.
# Found 2000 files belonging to 2 classes.

# %%
import numpy as np
import tensorflow as tf
random_numbers = np.random.normal(size=(1000, 16))
dataset = tf.data.Dataset.from_tensor_slices(random_numbers)

# %%
for i, element in enumerate(dataset):
    print(element.shape)
    if i >= 2:
        break
# Out:
# (16,)
# (16,)
# (16,)

# %%
batched_dataset = dataset.batch(32)
for i, element in enumerate(batched_dataset):
    print(element.shape)
    if i >= 2:
        break
# Out:
# (32, 16)
# (32, 16)
# (32, 16)

# %%
reshaped_dataset = dataset.map(lambda x: tf.reshape(x, (4, 4)))
for i, element in enumerate(reshaped_dataset):
    print(element.shape)
    if i >= 2:
        break
# Out:
# (4, 4)
# (4, 4)
# (4, 4)

# %%
reshaped_dataset = dataset.map(lambda x: tf.reshape(x, (4, 4))).batch(32)
for i, element in enumerate(reshaped_dataset):
    print(element.shape)
    if i >= 2:
        break
# Out:
# (32, 4, 4)
# (32, 4, 4)
# (32, 4, 4)

# %% [markdown]
# **Displaying the shapes of the data and labels yielded by the `Dataset`**

# %%
for data_batch, labels_batch in train_dataset:
    print("data batch shape:", data_batch.shape)
    print("labels batch shape:", labels_batch.shape)
    break
# Out:
# data batch shape: (32, 180, 180, 3)
# labels batch shape: (32,)

# %% [markdown]
# **Fitting the model using a `Dataset`**

# %%
callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="convnet_from_scratch.keras",
        save_best_only=True,
        monitor="val_loss")
]
history = model.fit(
    train_dataset,
    epochs=30,
    validation_data=validation_dataset,
    callbacks=callbacks)
# Out:
# Epoch 1/30
# 63/63 [==============================] - 13s 155ms/step - loss: 0.7267 - accuracy: 0.5200 - val_loss: 0.6974 - val_accuracy: 0.5000
# Epoch 2/30
# 63/63 [==============================] - 7s 111ms/step - loss: 0.6962 - accuracy: 0.5260 - val_loss: 0.6807 - val_accuracy: 0.5220
# Epoch 3/30
# 63/63 [==============================] - 7s 112ms/step - loss: 0.6834 - accuracy: 0.5950 - val_loss: 0.6454 - val_accuracy: 0.6420
# Epoch 4/30
# 63/63 [==============================] - 7s 110ms/step - loss: 0.6403 - accuracy: 0.6380 - val_loss: 0.9231 - val_accuracy: 0.5330
# Epoch 5/30
# 63/63 [==============================] - 7s 111ms/step - loss: 0.6087 - accuracy: 0.6730 - val_loss: 0.5891 - val_accuracy: 0.6970
# Epoch 6/30
# 63/63 [==============================] - 8s 130ms/step - loss: 0.5603 - accuracy: 0.7070 - val_loss: 0.5785 - val_accuracy: 0.7080
# Epoch 7/30
# ...

# %% [markdown]
# **Displaying curves of loss and accuracy during training**

# %%
import matplotlib.pyplot as plt
accuracy = history.history["accuracy"]
val_accuracy = history.history["val_accuracy"]
loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = range(1, len(accuracy) + 1)
plt.plot(epochs, accuracy, "bo", label="Training accuracy")
plt.plot(epochs, val_accuracy, "b", label="Validation accuracy")
plt.title("Training and validation accuracy")
plt.legend()
plt.figure()
plt.plot(epochs, loss, "bo", label="Training loss")
plt.plot(epochs, val_loss, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.legend()
plt.show()

# %% [markdown]
# **Evaluating the model on the test set**

# %%
test_model = keras.models.load_model("convnet_from_scratch.keras")
test_loss, test_acc = test_model.evaluate(test_dataset)
print(f"Test accuracy: {test_acc:.3f}")
# Out:
# 63/63 [==============================] - 4s 50ms/step - loss: 0.5664 - accuracy: 0.7100
# Test accuracy: 0.710
